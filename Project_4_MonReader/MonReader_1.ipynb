# %% [markdown]
# ## MonReader

# %% [markdown]
# In this project, images containing document pages being flipped or being held straight (no flipping) are used to train a Support Vector Machine model which is then used to predict if pages are being flipped or not in test images

# %%
import os
import shutil #file management module
import cv2 #openCV module
import pywt #wavelet transform module
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#the following function copied from StackOverflow converts an image to a B&W image using wavelet transform. 

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
#define paths which contain training and testing images
training_data_path = './images/training/'
testing_data_path = './images/testing/'

# %%
#create a list of directories that contain TRAINING images
training_img_dirs = []
for entry in os.scandir(training_data_path):
    if entry.is_dir: #if entry is a directory
        training_img_dirs.append(entry.path) #append the directory path to the list

# %%
training_img_dirs
# Out:
# ['./images/training/flip', './images/training/notflip']

# %%
#create a list of directories that containg TESTING images
testing_img_dirs = []

for entry in os.scandir(testing_data_path):
    if entry.is_dir:
        testing_img_dirs.append(entry.path)

# %%
testing_img_dirs
# Out:
# ['./images/testing/flip', './images/testing/notflip']

# %%
# for the training data, create a list of arrays representing the stacked arrays os resized original images and 
# resized wavelet transformed images along with a list of labels (flip or nonflip)

X = [] # independent variable list
y = [] # dependent varibale list

for img_dir in training_img_dirs:
    for file in os.scandir(img_dir):
        img = cv2.imread(file.path) #read the image file
        scaled_img = cv2.resize(img, (32,32)) #resize the image
        wave_trans_img = w2d(img, 'db1', 5) #wavelet transform the original image
        scaled_wave_trans_img = cv2.resize(wave_trans_img, (32,32)) #resize the wavelet transformed image
        # now vertically stack the resized original image and resized wavelet transformed image
        combined_image = np.vstack((scaled_img.reshape(32*32*3,1),scaled_wave_trans_img.reshape(32*32,1)))
        X.append(combined_image)#append to the X list
        #create y list (dependent varibale)
        if 'notflip' in img_dir:
            y.append(0)
        else:
            y.append(1)

# %%
#create deep copies of X and y
X_train = X[:]
y_train = y[:]

# %%
X_train[0]
# Out:
# array([[118],
#        [138],
#        [143],
#        ...,
#        [  0],
#        [  0],
#        [  0]], dtype=uint8)

# %%
len(X_train[0])
# Out:
# 4096

# %%
test = X_train[0].flatten()
len(test)
# Out:
# 4096

# %%
len(X_train[0])
# Out:
# 4096

# %%
# flatten the arrays for each image for training the SVC model
X_train_flat = np.array(X_train).reshape(len(X_train),4096).astype(float)
X_train_flat
# Out:
# array([[118., 138., 143., ...,   0.,   0.,   0.],
#        [118., 138., 143., ...,   0.,   0.,   0.],
#        [114., 139., 141., ...,   0.,   0.,   0.],
#        ...,
#        [153., 169., 168., ...,   3., 253.,   0.],
#        [153., 169., 168., ..., 238.,   1., 254.],
#        [153., 168., 169., ..., 222.,   1.,  96.]])

# %%
#create similar arrays of stacked images as above but now for the testing images as well as labels

X_test = [] # independent variable list
y_test = [] # dependent varibale list

for img_dir in testing_img_dirs:
    for file in os.scandir(img_dir):
        print(file.path) #print the file path just to keep track of the progress
        img = cv2.imread(file.path) #read the image file
        scaled_img = cv2.resize(img, (32,32)) #resize the image
        wave_trans_img = w2d(img, 'db1', 5) #wavelet transform the original image
        scaled_wave_trans_img = cv2.resize(wave_trans_img, (32,32))
        # now vertically stack the resized original image and resized wavelet transformed image
        combined_image = np.vstack((scaled_img.reshape(32*32*3,1),scaled_wave_trans_img.reshape(32*32,1)))
        X_test.append(combined_image) #append the stacked images to the list
        #create the y list
        if 'notflip' in img_dir:
            y_test.append(0)
        else:
            y_test.append(1)
# Out:
# ./images/testing/flip\0001_000000020.jpg
# ./images/testing/flip\0002_000000012.jpg
# ./images/testing/flip\0002_000000013.jpg
# ./images/testing/flip\0002_000000015.jpg
# ./images/testing/flip\0002_000000017.jpg
# ./images/testing/flip\0003_000000005.jpg
# ./images/testing/flip\0003_000000008.jpg
# ./images/testing/flip\0003_000000022.jpg
# ./images/testing/flip\0003_000000025.jpg
# ./images/testing/flip\0004_000000006.jpg
# ./images/testing/flip\0004_000000013.jpg
# ./images/testing/flip\0004_000000014.jpg
# ./images/testing/flip\0004_000000027.jpg
# ./images/testing/flip\0005_000000003.jpg
# ./images/testing/flip\0005_000000008.jpg
# ./images/testing/flip\0005_000000018.jpg
# ./images/testing/flip\0005_000000023.jpg
# ./images/testing/flip\0005_000000028.jpg
# ./images/testing/flip\0006_000000001.jpg
# ./images/testing/flip\0006_000000006.jpg
# ./images/testing/flip\0006_000000008.jpg
# ./images/testing/flip\0006_000000012.jpg
# ./images/testing/flip\0006_000000021.jpg
# ./images/testing/flip\0006_000000022.jpg
# ./images/testing/flip\0006_000000024.jpg
# ./images/testing/flip\0006_000000025.jpg
# ./images/testing/flip\0006_000000030.jpg
# ./images/testing/flip\0007_000000008.jpg
# ./images/testing/flip\0007_000000018.jpg
# ./images/testing/flip\0007_000000024.jpg
# ./images/testing/flip\0008_000000005.jpg
# ./images/testing/flip\0008_000000007.jpg
# ./images/testing/flip\0008_000000023.jpg
# ./images/testing/flip\0008_000000026.jpg
# ./images/testing/flip\0008_000000029.jpg
# ./images/testing/flip\0009_000000007.jpg
# ./images/testing/flip\0009_000000016.jpg
# ./images/testing/flip\0009_000000019.jpg
# ./images/testing/flip\0009_000000020.jpg
# ./images/testing/flip\0009_000000023.jpg
# ./images/testing/flip\0009_000000025.jpg
# ./images/testing/flip\0009_000000026.jpg
# ./images/testing/flip\0010_000000004.jpg
# ./images/testing/flip\0010_000000008.jpg
# ./images/testing/flip\0010_000000009.jpg
# ./images/testing/flip\0010_000000012.jpg
# ./images/testing/flip\0010_000000013.jpg
# ./images/testing/flip\0010_000000021.jpg
# ./images/testing/flip\0011_000000006.jpg
# ./images/testing/flip\0011_000000014.jpg
# ./images/testing/flip\0011_000000023.jpg
# ./images/testing/flip\0011_000000026.jpg
# ./images/testing/flip\0011_000000027.jpg
# ./images/testing/flip\0012_000000007.jpg
# ./images/testing/flip\0012_000000008.jpg
# ./images/testing/flip\0012_000000016.jpg
# ./images/testing/flip\0012_000000022.jpg
# ./images/testing/flip\0012_000000025.jpg
# ./images/testing/flip\0012_000000029.jpg
# ./images/testing/flip\0012_000000030.jpg
# ./images/testing/flip\0013_000000008.jpg
# ./images/testing/flip\0013_000000011.jpg
# ./images/testing/flip\0013_000000013.jpg
# ./images/testing/flip\0013_000000015.jpg
# ./images/testing/flip\0013_000000022.jpg
# ./images/testing/flip\0014_000000003.jpg
# ./images/testing/flip\0014_000000004.jpg
# ./images/testing/flip\0014_000000006.jpg
# ./images/testing/flip\0014_000000009.jpg
# ./images/testing/flip\0014_000000010.jpg
# ./images/testing/flip\0014_000000012.jpg
# ./images/testing/flip\0014_000000013.jpg
# ./images/testing/flip\0014_000000014.jpg
# ./images/testing/flip\0014_000000016.jpg
# ./images/testing/flip\0014_000000019.jpg
# ./images/testing/flip\0014_000000020.jpg
# ./images/testing/flip\0015_000000011.jpg
# ./images/testing/flip\0015_000000019.jpg
# ./images/testing/flip\0015_000000021.jpg
# ./images/testing/flip\0015_000000023.jpg
# ./images/testing/flip\0015_000000029.jpg
# ./images/testing/flip\0016_000000004.jpg
# ./images/testing/flip\0016_000000006.jpg
# ./images/testing/flip\0016_000000008.jpg
# ./images/testing/flip\0016_000000013.jpg
# ./images/testing/flip\0016_000000026.jpg
# ./images/testing/flip\0017_000000015.jpg
# ./images/testing/flip\0017_000000017.jpg
# ./images/testing/flip\0018_000000003.jpg
# ./images/testing/flip\0018_000000004.jpg
# ./images/testing/flip\0018_000000012.jpg
# ./images/testing/flip\0018_000000019.jpg
# ./images/testing/flip\0018_000000020.jpg
# ./images/testing/flip\0019_000000014.jpg
# ./images/testing/flip\0019_000000025.jpg
# ./images/testing/flip\0020_000000010.jpg
# ./images/testing/flip\0020_000000012.jpg
# ./images/testing/flip\0020_000000015.jpg
# ./images/testing/flip\0020_000000019.jpg
# ./images/testing/flip\0020_000000020.jpg
# ./images/testing/flip\0020_000000023.jpg
# ./images/testing/flip\0021_000000011.jpg
# ./images/testing/flip\0021_000000014.jpg
# ./images/testing/flip\0021_000000015.jpg
# ./images/testing/flip\0021_000000027.jpg
# ./images/testing/flip\0022_000000010.jpg
# ./images/testing/flip\0022_000000020.jpg
# ./images/testing/flip\0024_000000017.jpg
# ./images/testing/flip\0024_000000019.jpg
# ./images/testing/flip\0024_000000021.jpg
# ./images/testing/flip\0026_000000010.jpg
# ./images/testing/flip\0026_000000016.jpg
# ./images/testing/flip\0026_000000018.jpg
# ./images/testing/flip\0027_000000016.jpg
# ./images/testing/flip\0027_000000018.jpg
# ./images/testing/flip\0027_000000019.jpg
# ./images/testing/flip\0028_000000015.jpg
# ./images/testing/flip\0028_000000019.jpg
# ./images/testing/flip\0028_000000024.jpg
# ./images/testing/flip\0029_000000021.jpg
# ./images/testing/flip\0029_000000024.jpg
# ./images/testing/flip\0029_000000025.jpg
# ./images/testing/flip\0029_000000027.jpg
# ./images/testing/flip\0030_000000003.jpg
# ./images/testing/flip\0030_000000006.jpg
# ./images/testing/flip\0030_000000009.jpg
# ./images/testing/flip\0030_000000012.jpg
# ./images/testing/flip\0030_000000019.jpg
# ./images/testing/flip\0030_000000027.jpg
# ./images/testing/flip\0030_000000031.jpg
# ./images/testing/flip\0030_000000038.jpg
# ./images/testing/flip\0031_000000018.jpg
# ./images/testing/flip\0031_000000020.jpg
# ./images/testing/flip\0031_000000028.jpg
# ./images/testing/flip\0032_000000010.jpg
# ./images/testing/flip\0033_000000016.jpg
# ./images/testing/flip\0033_000000021.jpg
# ./images/testing/flip\0034_000000015.jpg
# ./images/testing/flip\0034_000000016.jpg
# ./images/testing/flip\0034_000000019.jpg
# ./images/testing/flip\0034_000000020.jpg
# ./images/testing/flip\0034_000000022.jpg
# ./images/testing/flip\0035_000000007.jpg
# ./images/testing/flip\0035_000000010.jpg
# ./images/testing/flip\0035_000000016.jpg
# ./images/testing/flip\0036_000000007.jpg
# ./images/testing/flip\0036_000000008.jpg
# ./images/testing/flip\0036_000000009.jpg
# ./images/testing/flip\0036_000000011.jpg
# ./images/testing/flip\0036_000000014.jpg
# ./images/testing/flip\0036_000000015.jpg
# ./images/testing/flip\0036_000000024.jpg
# ./images/testing/flip\0037_000000006.jpg
# ./images/testing/flip\0037_000000008.jpg
# ./images/testing/flip\0037_000000011.jpg
# ./images/testing/flip\0037_000000013.jpg
# ./images/testing/flip\0037_000000016.jpg
# ./images/testing/flip\0037_000000017.jpg
# ./images/testing/flip\0037_000000020.jpg
# ./images/testing/flip\0037_000000024.jpg
# ./images/testing/flip\0038_000000007.jpg
# ./images/testing/flip\0038_000000010.jpg
# ./images/testing/flip\0038_000000013.jpg
# ./images/testing/flip\0038_000000015.jpg
# ./images/testing/flip\0038_000000016.jpg
# ./images/testing/flip\0038_000000020.jpg
# ./images/testing/flip\0038_000000026.jpg
# ./images/testing/flip\0038_000000032.jpg
# ./images/testing/flip\0038_000000043.jpg
# ./images/testing/flip\0038_000000044.jpg
# ./images/testing/flip\0038_000000047.jpg
# ./images/testing/flip\0038_000000048.jpg
# ./images/testing/flip\0039_000000009.jpg
# ./images/testing/flip\0040_000000007.jpg
# ./images/testing/flip\0040_000000024.jpg
# ./images/testing/flip\0040_000000025.jpg
# ./images/testing/flip\0040_000000028.jpg
# ./images/testing/flip\0041_000000010.jpg
# ./images/testing/flip\0041_000000015.jpg
# ./images/testing/flip\0041_000000018.jpg
# ./images/testing/flip\0041_000000019.jpg
# ./images/testing/flip\0041_000000021.jpg
# ./images/testing/flip\0041_000000022.jpg
# ./images/testing/flip\0041_000000027.jpg
# ./images/testing/flip\0042_000000002.jpg
# ./images/testing/flip\0042_000000004.jpg
# ./images/testing/flip\0042_000000006.jpg
# ./images/testing/flip\0042_000000011.jpg
# ./images/testing/flip\0042_000000012.jpg
# ./images/testing/flip\0042_000000027.jpg
# ./images/testing/flip\0043_000000015.jpg
# ./images/testing/flip\0043_000000023.jpg
# ./images/testing/flip\0044_000000003.jpg
# ./images/testing/flip\0044_000000007.jpg
# ./images/testing/flip\0044_000000015.jpg
# ./images/testing/flip\0044_000000024.jpg
# ./images/testing/flip\0044_000000025.jpg
# ./images/testing/flip\0045_000000027.jpg
# ./images/testing/flip\0046_000000006.jpg
# ./images/testing/flip\0046_000000010.jpg
# ./images/testing/flip\0046_000000012.jpg
# ./images/testing/flip\0046_000000013.jpg
# ./images/testing/flip\0046_000000016.jpg
# ./images/testing/flip\0046_000000018.jpg
# ./images/testing/flip\0046_000000019.jpg
# ./images/testing/flip\0046_000000023.jpg
# ./images/testing/flip\0046_000000025.jpg
# ./images/testing/flip\0047_000000010.jpg
# ./images/testing/flip\0047_000000015.jpg
# ./images/testing/flip\0047_000000021.jpg
# ./images/testing/flip\0047_000000026.jpg
# ./images/testing/flip\0048_000000010.jpg
# ./images/testing/flip\0048_000000011.jpg
# ./images/testing/flip\0049_000000017.jpg
# ./images/testing/flip\0049_000000019.jpg
# ./images/testing/flip\0049_000000023.jpg
# ./images/testing/flip\0049_000000025.jpg
# ./images/testing/flip\0049_000000027.jpg
# ./images/testing/flip\0050_000000023.jpg
# ./images/testing/flip\0050_000000024.jpg
# ./images/testing/flip\0051_000000021.jpg
# ./images/testing/flip\0051_000000022.jpg
# ./images/testing/flip\0052_000000017.jpg
# ./images/testing/flip\0052_000000018.jpg
# ./images/testing/flip\0052_000000021.jpg
# ./images/testing/flip\0053_000000008.jpg
# ./images/testing/flip\0053_000000012.jpg
# ./images/testing/flip\0053_000000015.jpg
# ./images/testing/flip\0053_000000018.jpg
# ./images/testing/flip\0054_000000010.jpg
# ./images/testing/flip\0054_000000011.jpg
# ./images/testing/flip\0054_000000015.jpg
# ./images/testing/flip\0054_000000019.jpg
# ./images/testing/flip\0054_000000024.jpg
# ./images/testing/flip\0054_000000027.jpg
# ./images/testing/flip\0055_000000015.jpg
# ./images/testing/flip\0055_000000024.jpg
# ./images/testing/flip\0055_000000027.jpg
# ./images/testing/flip\0055_000000028.jpg
# ./images/testing/flip\0056_000000016.jpg
# ./images/testing/flip\0056_000000030.jpg
# ./images/testing/flip\0057_000000019.jpg
# ./images/testing/flip\0057_000000030.jpg
# ./images/testing/flip\0058_000000003.jpg
# ./images/testing/flip\0058_000000004.jpg
# ./images/testing/flip\0058_000000006.jpg
# ./images/testing/flip\0058_000000019.jpg
# ./images/testing/flip\0058_000000021.jpg
# ./images/testing/flip\0058_000000027.jpg
# ./images/testing/flip\0059_000000015.jpg
# ./images/testing/flip\0059_000000016.jpg
# ./images/testing/flip\0059_000000017.jpg
# ./images/testing/flip\0059_000000020.jpg
# ./images/testing/flip\0059_000000028.jpg
# ./images/testing/flip\0060_000000004.jpg
# ./images/testing/flip\0060_000000006.jpg
# ./images/testing/flip\0060_000000008.jpg
# ./images/testing/flip\0060_000000013.jpg
# ./images/testing/flip\0060_000000032.jpg
# ./images/testing/flip\0060_000000037.jpg
# ./images/testing/flip\0060_000000038.jpg
# ./images/testing/flip\0060_000000043.jpg
# ./images/testing/flip\0060_000000044.jpg
# ./images/testing/flip\0060_000000052.jpg
# ./images/testing/flip\0060_000000053.jpg
# ./images/testing/flip\0060_000000055.jpg
# ./images/testing/flip\0061_000000010.jpg
# ./images/testing/flip\0061_000000011.jpg
# ./images/testing/flip\0061_000000018.jpg
# ./images/testing/flip\0061_000000026.jpg
# ./images/testing/flip\0061_000000027.jpg
# ./images/testing/flip\0061_000000029.jpg
# ./images/testing/flip\0062_000000003.jpg
# ./images/testing/flip\0062_000000006.jpg
# ./images/testing/flip\0062_000000009.jpg
# ./images/testing/flip\0062_000000011.jpg
# ./images/testing/flip\0062_000000012.jpg
# ./images/testing/flip\0062_000000013.jpg
# ./images/testing/flip\0062_000000018.jpg
# ./images/testing/flip\0062_000000020.jpg
# ./images/testing/flip\0063_000000011.jpg
# ./images/testing/flip\0063_000000014.jpg
# ./images/testing/flip\0063_000000023.jpg
# ./images/testing/flip\0064_000000027.jpg
# ./images/testing/flip\0065_000000001.jpg
# ./images/testing/flip\0065_000000005.jpg
# ./images/testing/flip\0065_000000016.jpg
# ./images/testing/flip\0065_000000023.jpg
# ./images/testing/flip\0065_000000025.jpg
# ./images/testing/flip\0065_000000026.jpg
# ./images/testing/notflip\0001_000000002.jpg
# ./images/testing/notflip\0001_000000004.jpg
# ./images/testing/notflip\0001_000000009.jpg
# ./images/testing/notflip\0001_000000014.jpg
# ./images/testing/notflip\0001_000000024.jpg
# ./images/testing/notflip\0002_000000003.jpg
# ./images/testing/notflip\0002_000000006.jpg
# ./images/testing/notflip\0002_000000008.jpg
# ./images/testing/notflip\0002_000000012.jpg
# ./images/testing/notflip\0002_000000015.jpg
# ./images/testing/notflip\0002_000000026.jpg
# ./images/testing/notflip\0002_000000027.jpg
# ./images/testing/notflip\0002_000000028.jpg
# ./images/testing/notflip\0003_000000004.jpg
# ./images/testing/notflip\0003_000000018.jpg
# ./images/testing/notflip\0003_000000025.jpg
# ./images/testing/notflip\0003_000000030.jpg
# ./images/testing/notflip\0004_000000002.jpg
# ./images/testing/notflip\0004_000000004.jpg
# ./images/testing/notflip\0004_000000010.jpg
# ./images/testing/notflip\0004_000000012.jpg
# ./images/testing/notflip\0004_000000015.jpg
# ./images/testing/notflip\0004_000000016.jpg
# ./images/testing/notflip\0004_000000020.jpg
# ./images/testing/notflip\0004_000000023.jpg
# ./images/testing/notflip\0004_000000029.jpg
# ./images/testing/notflip\0005_000000005.jpg
# ./images/testing/notflip\0005_000000009.jpg
# ./images/testing/notflip\0005_000000012.jpg
# ./images/testing/notflip\0005_000000018.jpg
# ./images/testing/notflip\0005_000000022.jpg
# ./images/testing/notflip\0006_000000009.jpg
# ./images/testing/notflip\0006_000000015.jpg
# ./images/testing/notflip\0006_000000016.jpg
# ./images/testing/notflip\0006_000000019.jpg
# ./images/testing/notflip\0006_000000021.jpg
# ./images/testing/notflip\0006_000000023.jpg
# ./images/testing/notflip\0006_000000025.jpg
# ./images/testing/notflip\0006_000000027.jpg
# ./images/testing/notflip\0006_000000028.jpg
# ./images/testing/notflip\0006_000000029.jpg
# ./images/testing/notflip\0007_000000010.jpg
# ./images/testing/notflip\0007_000000025.jpg
# ./images/testing/notflip\0008_000000008.jpg
# ./images/testing/notflip\0008_000000009.jpg
# ./images/testing/notflip\0008_000000012.jpg
# ./images/testing/notflip\0008_000000013.jpg
# ./images/testing/notflip\0008_000000020.jpg
# ./images/testing/notflip\0008_000000023.jpg
# ./images/testing/notflip\0009_000000002.jpg
# ./images/testing/notflip\0009_000000003.jpg
# ./images/testing/notflip\0009_000000004.jpg
# ./images/testing/notflip\0009_000000005.jpg
# ./images/testing/notflip\0009_000000012.jpg
# ./images/testing/notflip\0009_000000015.jpg
# ./images/testing/notflip\0009_000000017.jpg
# ./images/testing/notflip\0009_000000027.jpg
# ./images/testing/notflip\0010_000000007.jpg
# ./images/testing/notflip\0010_000000009.jpg
# ./images/testing/notflip\0010_000000026.jpg
# ./images/testing/notflip\0011_000000017.jpg
# ./images/testing/notflip\0011_000000018.jpg
# ./images/testing/notflip\0011_000000027.jpg
# ./images/testing/notflip\0015_000000002.jpg
# ./images/testing/notflip\0015_000000003.jpg
# ./images/testing/notflip\0015_000000004.jpg
# ./images/testing/notflip\0015_000000005.jpg
# ./images/testing/notflip\0015_000000018.jpg
# ./images/testing/notflip\0015_000000021.jpg
# ./images/testing/notflip\0016_000000001.jpg
# ./images/testing/notflip\0016_000000014.jpg
# ./images/testing/notflip\0016_000000020.jpg
# ./images/testing/notflip\0016_000000023.jpg
# ./images/testing/notflip\0016_000000025.jpg
# ./images/testing/notflip\0019_000000002.jpg
# ./images/testing/notflip\0019_000000004.jpg
# ./images/testing/notflip\0019_000000012.jpg
# ./images/testing/notflip\0019_000000015.jpg
# ./images/testing/notflip\0019_000000024.jpg
# ./images/testing/notflip\0019_000000025.jpg
# ./images/testing/notflip\0019_000000027.jpg
# ./images/testing/notflip\0020_000000004.jpg
# ./images/testing/notflip\0020_000000010.jpg
# ./images/testing/notflip\0020_000000016.jpg
# ./images/testing/notflip\0020_000000019.jpg
# ./images/testing/notflip\0021_000000024.jpg
# ./images/testing/notflip\0021_000000026.jpg
# ./images/testing/notflip\0023_000000014.jpg
# ./images/testing/notflip\0023_000000020.jpg
# ./images/testing/notflip\0023_000000024.jpg
# ./images/testing/notflip\0023_000000029.jpg
# ./images/testing/notflip\0023_000000030.jpg
# ./images/testing/notflip\0024_000000002.jpg
# ./images/testing/notflip\0024_000000004.jpg
# ./images/testing/notflip\0024_000000006.jpg
# ./images/testing/notflip\0024_000000007.jpg
# ./images/testing/notflip\0024_000000019.jpg
# ./images/testing/notflip\0024_000000020.jpg
# ./images/testing/notflip\0024_000000022.jpg
# ./images/testing/notflip\0024_000000024.jpg
# ./images/testing/notflip\0024_000000025.jpg
# ./images/testing/notflip\0025_000000010.jpg
# ./images/testing/notflip\0025_000000011.jpg
# ./images/testing/notflip\0025_000000013.jpg
# ./images/testing/notflip\0025_000000018.jpg
# ./images/testing/notflip\0025_000000021.jpg
# ./images/testing/notflip\0025_000000022.jpg
# ./images/testing/notflip\0025_000000025.jpg
# ./images/testing/notflip\0026_000000004.jpg
# ./images/testing/notflip\0026_000000005.jpg
# ./images/testing/notflip\0026_000000010.jpg
# ./images/testing/notflip\0026_000000014.jpg
# ./images/testing/notflip\0026_000000024.jpg
# ./images/testing/notflip\0026_000000029.jpg
# ./images/testing/notflip\0027_000000001.jpg
# ./images/testing/notflip\0027_000000004.jpg
# ./images/testing/notflip\0027_000000010.jpg
# ./images/testing/notflip\0027_000000013.jpg
# ./images/testing/notflip\0027_000000017.jpg
# ./images/testing/notflip\0027_000000022.jpg
# ./images/testing/notflip\0027_000000023.jpg
# ./images/testing/notflip\0028_000000004.jpg
# ./images/testing/notflip\0028_000000024.jpg
# ./images/testing/notflip\0029_000000001.jpg
# ./images/testing/notflip\0029_000000003.jpg
# ./images/testing/notflip\0029_000000004.jpg
# ./images/testing/notflip\0029_000000005.jpg
# ./images/testing/notflip\0029_000000013.jpg
# ./images/testing/notflip\0029_000000017.jpg
# ./images/testing/notflip\0029_000000018.jpg
# ./images/testing/notflip\0029_000000019.jpg
# ./images/testing/notflip\0029_000000025.jpg
# ./images/testing/notflip\0030_000000001.jpg
# ./images/testing/notflip\0030_000000004.jpg
# ./images/testing/notflip\0030_000000007.jpg
# ./images/testing/notflip\0030_000000018.jpg
# ./images/testing/notflip\0030_000000022.jpg
# ./images/testing/notflip\0030_000000023.jpg
# ./images/testing/notflip\0030_000000024.jpg
# ./images/testing/notflip\0030_000000028.jpg
# ./images/testing/notflip\0031_000000004.jpg
# ./images/testing/notflip\0031_000000008.jpg
# ./images/testing/notflip\0031_000000010.jpg
# ./images/testing/notflip\0031_000000015.jpg
# ./images/testing/notflip\0031_000000016.jpg
# ./images/testing/notflip\0031_000000017.jpg
# ./images/testing/notflip\0031_000000019.jpg
# ./images/testing/notflip\0031_000000020.jpg
# ./images/testing/notflip\0032_000000003.jpg
# ./images/testing/notflip\0032_000000007.jpg
# ./images/testing/notflip\0032_000000008.jpg
# ./images/testing/notflip\0032_000000010.jpg
# ./images/testing/notflip\0032_000000015.jpg
# ./images/testing/notflip\0032_000000029.jpg
# ./images/testing/notflip\0033_000000002.jpg
# ./images/testing/notflip\0033_000000005.jpg
# ./images/testing/notflip\0033_000000006.jpg
# ./images/testing/notflip\0033_000000008.jpg
# ./images/testing/notflip\0033_000000015.jpg
# ./images/testing/notflip\0033_000000019.jpg
# ./images/testing/notflip\0033_000000025.jpg
# ./images/testing/notflip\0033_000000027.jpg
# ./images/testing/notflip\0034_000000008.jpg
# ./images/testing/notflip\0034_000000017.jpg
# ./images/testing/notflip\0034_000000025.jpg
# ./images/testing/notflip\0034_000000030.jpg
# ./images/testing/notflip\0035_000000009.jpg
# ./images/testing/notflip\0035_000000011.jpg
# ./images/testing/notflip\0035_000000015.jpg
# ./images/testing/notflip\0035_000000016.jpg
# ./images/testing/notflip\0035_000000026.jpg
# ./images/testing/notflip\0036_000000001.jpg
# ./images/testing/notflip\0036_000000004.jpg
# ./images/testing/notflip\0036_000000005.jpg
# ./images/testing/notflip\0036_000000014.jpg
# ./images/testing/notflip\0036_000000020.jpg
# ./images/testing/notflip\0036_000000025.jpg
# ./images/testing/notflip\0036_000000028.jpg
# ./images/testing/notflip\0036_000000030.jpg
# ./images/testing/notflip\0037_000000002.jpg
# ./images/testing/notflip\0037_000000004.jpg
# ./images/testing/notflip\0037_000000007.jpg
# ./images/testing/notflip\0037_000000008.jpg
# ./images/testing/notflip\0037_000000010.jpg
# ./images/testing/notflip\0037_000000014.jpg
# ./images/testing/notflip\0037_000000015.jpg
# ./images/testing/notflip\0037_000000018.jpg
# ./images/testing/notflip\0037_000000019.jpg
# ./images/testing/notflip\0037_000000025.jpg
# ./images/testing/notflip\0037_000000028.jpg
# ./images/testing/notflip\0038_000000005.jpg
# ./images/testing/notflip\0038_000000008.jpg
# ./images/testing/notflip\0038_000000009.jpg
# ./images/testing/notflip\0038_000000010.jpg
# ./images/testing/notflip\0038_000000011.jpg
# ./images/testing/notflip\0038_000000020.jpg
# ./images/testing/notflip\0038_000000022.jpg
# ./images/testing/notflip\0038_000000023.jpg
# ./images/testing/notflip\0039_000000003.jpg
# ./images/testing/notflip\0039_000000022.jpg
# ./images/testing/notflip\0039_000000026.jpg
# ./images/testing/notflip\0040_000000004.jpg
# ./images/testing/notflip\0040_000000005.jpg
# ./images/testing/notflip\0040_000000006.jpg
# ./images/testing/notflip\0040_000000007.jpg
# ./images/testing/notflip\0040_000000011.jpg
# ./images/testing/notflip\0040_000000012.jpg
# ./images/testing/notflip\0040_000000014.jpg
# ./images/testing/notflip\0040_000000016.jpg
# ./images/testing/notflip\0040_000000017.jpg
# ./images/testing/notflip\0040_000000018.jpg
# ./images/testing/notflip\0041_000000001.jpg
# ./images/testing/notflip\0041_000000003.jpg
# ./images/testing/notflip\0041_000000006.jpg
# ./images/testing/notflip\0041_000000011.jpg
# ./images/testing/notflip\0041_000000014.jpg
# ./images/testing/notflip\0041_000000015.jpg
# ./images/testing/notflip\0041_000000021.jpg
# ./images/testing/notflip\0041_000000022.jpg
# ./images/testing/notflip\0041_000000028.jpg
# ./images/testing/notflip\0041_000000034.jpg
# ./images/testing/notflip\0041_000000036.jpg
# ./images/testing/notflip\0042_000000001.jpg
# ./images/testing/notflip\0042_000000006.jpg
# ./images/testing/notflip\0042_000000007.jpg
# ./images/testing/notflip\0042_000000013.jpg
# ./images/testing/notflip\0042_000000021.jpg
# ./images/testing/notflip\0042_000000024.jpg
# ./images/testing/notflip\0042_000000027.jpg
# ./images/testing/notflip\0042_000000030.jpg
# ./images/testing/notflip\0043_000000023.jpg
# ./images/testing/notflip\0043_000000024.jpg
# ./images/testing/notflip\0043_000000026.jpg
# ./images/testing/notflip\0044_000000006.jpg
# ./images/testing/notflip\0044_000000014.jpg
# ./images/testing/notflip\0044_000000027.jpg
# ./images/testing/notflip\0045_000000005.jpg
# ./images/testing/notflip\0045_000000012.jpg
# ./images/testing/notflip\0045_000000013.jpg
# ./images/testing/notflip\0045_000000016.jpg
# ./images/testing/notflip\0045_000000018.jpg
# ./images/testing/notflip\0045_000000022.jpg
# ./images/testing/notflip\0045_000000026.jpg
# ./images/testing/notflip\0045_000000028.jpg
# ./images/testing/notflip\0045_000000030.jpg
# ./images/testing/notflip\0046_000000003.jpg
# ./images/testing/notflip\0046_000000011.jpg
# ./images/testing/notflip\0046_000000012.jpg
# ./images/testing/notflip\0046_000000027.jpg
# ./images/testing/notflip\0046_000000028.jpg
# ./images/testing/notflip\0047_000000006.jpg
# ./images/testing/notflip\0047_000000009.jpg
# ./images/testing/notflip\0047_000000024.jpg
# ./images/testing/notflip\0047_000000025.jpg
# ./images/testing/notflip\0047_000000029.jpg
# ./images/testing/notflip\0048_000000015.jpg
# ./images/testing/notflip\0048_000000025.jpg
# ./images/testing/notflip\0048_000000026.jpg
# ./images/testing/notflip\0048_000000030.jpg
# ./images/testing/notflip\0049_000000006.jpg
# ./images/testing/notflip\0049_000000011.jpg
# ./images/testing/notflip\0049_000000012.jpg
# ./images/testing/notflip\0049_000000018.jpg
# ./images/testing/notflip\0049_000000022.jpg
# ./images/testing/notflip\0049_000000026.jpg
# ./images/testing/notflip\0049_000000028.jpg
# ./images/testing/notflip\0050_000000011.jpg
# ./images/testing/notflip\0050_000000013.jpg
# ./images/testing/notflip\0051_000000002.jpg
# ./images/testing/notflip\0051_000000012.jpg
# ./images/testing/notflip\0051_000000025.jpg
# ./images/testing/notflip\0052_000000006.jpg
# ./images/testing/notflip\0052_000000014.jpg
# ./images/testing/notflip\0052_000000022.jpg
# ./images/testing/notflip\0052_000000029.jpg
# ./images/testing/notflip\0053_000000001.jpg
# ./images/testing/notflip\0053_000000008.jpg
# ./images/testing/notflip\0053_000000011.jpg
# ./images/testing/notflip\0053_000000016.jpg
# ./images/testing/notflip\0053_000000017.jpg
# ./images/testing/notflip\0053_000000025.jpg
# ./images/testing/notflip\0054_000000010.jpg
# ./images/testing/notflip\0054_000000020.jpg
# ./images/testing/notflip\0054_000000023.jpg
# ./images/testing/notflip\0054_000000027.jpg
# ./images/testing/notflip\0055_000000012.jpg
# ./images/testing/notflip\0055_000000013.jpg
# ./images/testing/notflip\0055_000000016.jpg
# ./images/testing/notflip\0056_000000004.jpg
# ./images/testing/notflip\0056_000000007.jpg
# ./images/testing/notflip\0056_000000011.jpg
# ./images/testing/notflip\0056_000000013.jpg
# ./images/testing/notflip\0056_000000022.jpg
# ./images/testing/notflip\0056_000000024.jpg
# ./images/testing/notflip\0056_000000027.jpg
# ./images/testing/notflip\0057_000000003.jpg
# ./images/testing/notflip\0057_000000007.jpg
# ./images/testing/notflip\0057_000000012.jpg
# ./images/testing/notflip\0057_000000023.jpg
# ./images/testing/notflip\0057_000000027.jpg
# ./images/testing/notflip\0058_000000002.jpg
# ./images/testing/notflip\0058_000000004.jpg
# ./images/testing/notflip\0058_000000013.jpg
# ./images/testing/notflip\0058_000000018.jpg
# ./images/testing/notflip\0058_000000020.jpg
# ./images/testing/notflip\0058_000000021.jpg
# ./images/testing/notflip\0058_000000025.jpg

# %%
X_test_flat = np.array(X_test).reshape(len(X_test),4096).astype(float)
X_test_flat
# Out:
# array([[110., 133., 135., ...,   0.,   0.,   0.],
#        [124., 144., 149., ...,   0.,   0.,   0.],
#        [124., 144., 149., ...,   0.,   0.,   0.],
#        ...,
#        [155., 169., 168., ...,   6., 251., 255.],
#        [155., 169., 168., ...,   6., 251., 255.],
#        [155., 169., 168., ...,   4., 249.,   0.]])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler #StandardScaler was used in the video. I will use MinMax to scale values between 0 and 1
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline #see below for Pipeline creation
from sklearn.metrics import classification_report

# %%
#create a sklearn pipeline 
pipe = Pipeline([('scaler', MinMaxScaler()), ('svc', SVC(kernel = 'rbf', C = 10))]) #create a simple pipeline of scaling the data
# and then applying the SVC model with the specified hyperparameters (these hyperparameters will be tuned later on)

# %%
pipe.fit(X_train_flat, y_train)
pipe.score(X_test_flat, y_test)
# Out:
# 1.0

# %%
y_predicted = pipe.predict(X_test_flat)

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       307
#            1       1.00      1.00      1.00       290
#
#     accuracy                           1.00       597
#    macro avg       1.00      1.00      1.00       597
# weighted avg       1.00      1.00      1.00       597

# %%
# I am somehow getting a perfect score for predicting the flip(1) and nonflip(0) images!! 
# I will have to go back over the code to see if there is any data leak
