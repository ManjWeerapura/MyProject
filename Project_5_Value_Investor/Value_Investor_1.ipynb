# %%
import pandas as pd
import numpy as np

# %%
trading_portfolio = pd.ExcelFile('trading_portfolio.xlsx')
trading_portfolio #load the Excel file with the data

# %%
trading_portfolio.sheet_names # output of this is a list of all the sheets within the Excel file
# catherefore, you can loop through the sheet names and load them into dataframes individually
# Out:
# ['Russia - Sberbank Rossii PAO (S',
#  'Turkey - Koc Holding AS (KCHOL)',
#  'Egypt - Medinet Nasr Housing (M',
#  'Brazil - Minerva SABrazil (BEEF',
#  'Argentina - Pampa Energia SA (P',
#  'Colombia - Cementos Argos SA (C',
#  'South Africa - Impala Platinum ',
#  'South Korea - Dongkuk Steel Mil']

# %%
# read one of the excel file sheets into a dataframe
df = pd.read_excel('trading_portfolio.xlsx', sheet_name = trading_portfolio.sheet_names[1])

# %%
df
# Out:
#                     Date          Price               Open            High  \
# 0    2021-03-31 00:00:00          19.41              19.42           19.63
# 1    2021-03-30 00:00:00           19.5              19.12           19.81
# 2    2021-03-29 00:00:00           19.1              19.24           19.67
# 3    2021-03-26 00:00:00          19.25              20.28           20.36
# 4    2021-03-25 00:00:00          20.02               20.5           20.86
# ..                   ...            ...                ...             ...
# 311  2020-01-07 00:00:00          19.93              20.22           20.28
# 312  2020-01-06 00:00:00          20.08              20.34           20.34
# 313  2020-01-03 00:00:00           20.3               20.3           20.44
# 314  2020-01-02 00:00:00          20.38              20.42           20.44
# 315       Highest: 25.48  Lowest: 12.38  Difference: 13.10  Average: 17.86
#
#                  Low    Vol.  Change %
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      316 non-null    object
#  1   Price     316 non-null    object
#  2   Open      316 non-null    object
#  3   High      316 non-null    object
#  4   Low       316 non-null    object
#  5   Vol.      315 non-null    object
#  6   Change %  315 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 17.4+ KB

# %%
df = df[:-1]

# %%
df
# Out:
#                     Date  Price   Open   High    Low    Vol.  Change %
# 0    2021-03-31 00:00:00  19.41  19.42  19.63  19.27  13.14M   -0.0046
# 1    2021-03-30 00:00:00   19.5  19.12  19.81  19.03  21.05M    0.0209
# 2    2021-03-29 00:00:00   19.1  19.24  19.67   19.1  16.56M   -0.0078
# 3    2021-03-26 00:00:00  19.25  20.28  20.36   19.1  21.35M   -0.0385
# 4    2021-03-25 00:00:00  20.02   20.5  20.86  20.02  15.93M   -0.0148
# ..                   ...    ...    ...    ...    ...     ...       ...
# 310  2020-01-08 00:00:00  19.94  19.89  19.95  19.66   2.79M    0.0005
# 311  2020-01-07 00:00:00  19.93  20.22  20.28  19.92   2.89M   -0.0075
# 312  2020-01-06 00:00:00  20.08  20.34  20.34  19.97   1.94M   -0.0108
# 313  2020-01-03 00:00:00   20.3   20.3  20.44  19.97   3.31M   -0.0039
# 314  2020-01-02 00:00:00  20.38  20.42  20.44  20.24   2.53M    0.0030
#
# [315 rows x 7 columns]

# %%
df[['Price','Open', 'High', 'Low', 'Change %']] = df[['Price','Open', 'High', 'Low', 'Change %']].apply(pd.to_numeric)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      315 non-null    object
#  1   Price     315 non-null    float64
#  2   Open      315 non-null    float64
#  3   High      315 non-null    float64
#  4   Low       315 non-null    float64
#  5   Vol.      315 non-null    object
#  6   Change %  315 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 17.4+ KB
# C:\Users\Manj\anaconda3\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <ipython-input-126-b9c6864122be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#           Date  Price   Open   High    Low    Vol.  Change %
# 0   2021-03-31  19.41  19.42  19.63  19.27  13.14M   -0.0046
# 1   2021-03-30  19.50  19.12  19.81  19.03  21.05M    0.0209
# 2   2021-03-29  19.10  19.24  19.67  19.10  16.56M   -0.0078
# 3   2021-03-26  19.25  20.28  20.36  19.10  21.35M   -0.0385
# 4   2021-03-25  20.02  20.50  20.86  20.02  15.93M   -0.0148
# ..         ...    ...    ...    ...    ...     ...       ...
# 310 2020-01-08  19.94  19.89  19.95  19.66   2.79M    0.0005
# 311 2020-01-07  19.93  20.22  20.28  19.92   2.89M   -0.0075
# 312 2020-01-06  20.08  20.34  20.34  19.97   1.94M   -0.0108
# 313 2020-01-03  20.30  20.30  20.44  19.97   3.31M   -0.0039
# 314 2020-01-02  20.38  20.42  20.44  20.24   2.53M    0.0030
#
# [315 rows x 7 columns]

# %%
df['Mean'] = df['Price'].rolling(20).mean()
# Out:
# <ipython-input-128-4143e733b0bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mean'] = df['Price'].rolling(20).mean()

# %%
df
# Out:
#           Date  Price   Open   High    Low    Vol.  Change %     Mean
# 0   2021-03-31  19.41  19.42  19.63  19.27  13.14M   -0.0046      NaN
# 1   2021-03-30   19.5  19.12  19.81  19.03  21.05M    0.0209      NaN
# 2   2021-03-29   19.1  19.24  19.67   19.1  16.56M   -0.0078      NaN
# 3   2021-03-26  19.25  20.28  20.36   19.1  21.35M   -0.0385      NaN
# 4   2021-03-25  20.02   20.5  20.86  20.02  15.93M   -0.0148      NaN
# ..         ...    ...    ...    ...    ...     ...       ...      ...
# 310 2020-01-08  19.94  19.89  19.95  19.66   2.79M    0.0005  20.5235
# 311 2020-01-07  19.93  20.22  20.28  19.92   2.89M   -0.0075  20.5350
# 312 2020-01-06  20.08  20.34  20.34  19.97   1.94M   -0.0108  20.5605
# 313 2020-01-03   20.3   20.3  20.44  19.97   3.31M   -0.0039  20.5985
# 314 2020-01-02  20.38  20.42  20.44  20.24   2.53M    0.0030  20.6105
#
# [315 rows x 8 columns]

# %%
df['Mean+2STD'] = df['Mean']+df['Price'].rolling(20).std()*2
# Out:
# <ipython-input-129-8c333c03b0d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mean+2STD'] = df['Mean']+df['Price'].rolling(20).std()*2

# %%
df
# Out:
#           Date  Price   Open   High    Low    Vol.  Change %     Mean  \
# 0   2021-03-31  19.41  19.42  19.63  19.27  13.14M   -0.0046      NaN
# 1   2021-03-30   19.5  19.12  19.81  19.03  21.05M    0.0209      NaN
# 2   2021-03-29   19.1  19.24  19.67   19.1  16.56M   -0.0078      NaN
# 3   2021-03-26  19.25  20.28  20.36   19.1  21.35M   -0.0385      NaN
# 4   2021-03-25  20.02   20.5  20.86  20.02  15.93M   -0.0148      NaN
# ..         ...    ...    ...    ...    ...     ...       ...      ...
# 310 2020-01-08  19.94  19.89  19.95  19.66   2.79M    0.0005  20.5235
# 311 2020-01-07  19.93  20.22  20.28  19.92   2.89M   -0.0075  20.5350
# 312 2020-01-06  20.08  20.34  20.34  19.97   1.94M   -0.0108  20.5605
# 313 2020-01-03   20.3   20.3  20.44  19.97   3.31M   -0.0039  20.5985
# 314 2020-01-02  20.38  20.42  20.44  20.24   2.53M    0.0030  20.6105
#
#         +2STD  Mean+2STD
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# ...

# %%
df['Mean-2STD'] = df['Mean']-df['Price'].rolling(20).std()*2
# Out:
# <ipython-input-130-bed0e523a2c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mean-2STD'] = df['Mean']-df['Price'].rolling(20).std()*2

# %%
df
# Out:
#           Date  Price   Open   High    Low    Vol.  Change %     Mean  \
# 0   2021-03-31  19.41  19.42  19.63  19.27  13.14M   -0.0046      NaN
# 1   2021-03-30  19.50  19.12  19.81  19.03  21.05M    0.0209      NaN
# 2   2021-03-29  19.10  19.24  19.67  19.10  16.56M   -0.0078      NaN
# 3   2021-03-26  19.25  20.28  20.36  19.10  21.35M   -0.0385      NaN
# 4   2021-03-25  20.02  20.50  20.86  20.02  15.93M   -0.0148      NaN
# ..         ...    ...    ...    ...    ...     ...       ...      ...
# 310 2020-01-08  19.94  19.89  19.95  19.66   2.79M    0.0005  20.5235
# 311 2020-01-07  19.93  20.22  20.28  19.92   2.89M   -0.0075  20.5350
# 312 2020-01-06  20.08  20.34  20.34  19.97   1.94M   -0.0108  20.5605
# 313 2020-01-03  20.30  20.30  20.44  19.97   3.31M   -0.0039  20.5985
# 314 2020-01-02  20.38  20.42  20.44  20.24   2.53M    0.0030  20.6105
#
#      Mean+2STD  Mean-2STD
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# ...

# %%
# drop the rwos will null values
df = df.dropna(axis=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.Mean.dtype
# Out:
# dtype('float64')

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = df['Date'], y = df['Mean'], color = 'orange', linewidth = 1)
sns.lineplot(x = df['Date'], y = df['Mean+2STD'], color = 'blue', linewidth = 2)
sns.lineplot(x = df['Date'], y = df['Mean-2STD'], color = 'red', linewidth = 2)
sns.lineplot(x = df['Date'], y = df['Price'], color = 'green', linewidth = 1)
plt.fill_between(x=df['Date'], y1 = df['Mean+2STD'], y2 = df['Mean-2STD'], color= 'grey', alpha = 0.3)
plt.legend(['Mean', 'Mean + 2STD', 'Mean - 2STD', 'Closing Price'])
